# %%
import firebase_admin
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from firebase_admin import credentials, firestore
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
import numpy as np

# Firebase Initialization
cred = credentials.Certificate("adminkey.json")
firebase_admin.initialize_app(cred)
db = firestore.client()

import logging
logging.basicConfig(filename='training_log.txt', level=logging.INFO, format='%(asctime)s - %(message)s')

# Constants
INCLUDE_ONLY = ['Stephen', 'Lillian', 'Ren', 'Yuanheng', 'Ethan']
ACTIVITIES = ['sit', 'walk', 'upstair','downstair']
CHUNK_SIZE = 0.5  # in seconds (can be a decimal)
SAMPLING_RATE = 100  # Hz
START_FROM, END_TO = 200, 300
NUM_CLASSES = 4

# %%
# Data Structures
def fetch_data(collection_name, activities, include_only, time_start=500, time_end=8000):
    """Fetch and preprocess data from Firestore."""
    data, docs = [], []
    for person in db.collection(collection_name).stream():
        person_name = str(person.to_dict().get('name', ''))
        if person_name not in include_only:
            continue

        for activity in activities:
            for recording in db.collection(collection_name).document(person_name).collection(activity).stream():
                record = recording.to_dict()
                if 'acceleration' not in record:
                    continue

                docs.append(record)
                df = pd.DataFrame(record['acceleration'])
                
                if 'time' in df.columns:
                    filtered_df = df[(df['time'] >= time_start) & (df['time'] <= time_end)]
                    data.append(filtered_df)
                else:
                    raise ValueError("The 'acceleration' field must include a 'time' column.")
    return data, docs

# Fetch and preprocess training/testing data
training_data_raw, training_docs = fetch_data("training", ACTIVITIES, INCLUDE_ONLY)
testing_data_raw, testing_docs = fetch_data("testing", ACTIVITIES, INCLUDE_ONLY)

# %%
# Function to chunk data into smaller segments for training/testing
def chunk_data(data_raw, docs, chunk_size, activities, sampling_rate):
    """Split data into chunks and assign labels."""
    data, labels = [], []
    activity_distribution = np.zeros(len(activities))
    chunk_samples = int(chunk_size * sampling_rate)  # Convert time to sample count

    for i in range(len(data_raw)):
        num_chunks = len(data_raw[i]) // chunk_samples  # Number of full chunks
        for j in range(num_chunks):
            start = j * chunk_samples
            end = start + chunk_samples
            x = list(data_raw[i]["x"])[start:end]
            y = list(data_raw[i]["y"])[start:end]
            z = list(data_raw[i]["z"])[start:end]
            activity = docs[i]['activity']
            label = activities.index(activity)

            activity_distribution[label] += 1
            data.append([x, y, z])
            labels.append(label)

    return data, labels, activity_distribution

# Chunk the data
training_data, training_labels, training_distribution = chunk_data(training_data_raw, training_docs, CHUNK_SIZE, ACTIVITIES, SAMPLING_RATE)
testing_data, testing_labels, testing_distribution = chunk_data(testing_data_raw, testing_docs, CHUNK_SIZE, ACTIVITIES, SAMPLING_RATE)

# %%
# Save function
def save_model(model, optimizer, filename="model.pth"):
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }
    torch.save(checkpoint, filename)
    print(f"Model saved to {filename}")
# Load function
def load_model(model, optimizer, filename="model.pth"):
    checkpoint = torch.load(filename)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    print(f"Model loaded from {filename}")

# %%
# Convert the data to NumPy arrays
training_data = np.array(training_data)
testing_data = np.array(testing_data)

# Normalize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(training_data.reshape(-1, training_data.shape[-1])).reshape(training_data.shape)
X_test = scaler.transform(testing_data.reshape(-1, testing_data.shape[-1])).reshape(testing_data.shape)

# Convert to torch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)  # Shape: (num_samples, 3, chunk_size*100)
y_train = torch.tensor(training_labels, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(testing_labels, dtype=torch.long)

# Create TensorDataset and DataLoader for batching
train_data = TensorDataset(X_train, y_train)
test_data = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False, pin_memory=True)

# %%
class OptimizedCNNModel(nn.Module):
    def __init__(self, num_classes, input_channels=3, seq_length=int(CHUNK_SIZE * 100)):
        super(OptimizedCNNModel, self).__init__()

        def depthwise_separable_conv(in_channels, out_channels, kernel_size=3, padding=1):
            """Depthwise Separable Convolution for efficiency."""
            return nn.Sequential(
                nn.Conv1d(in_channels, in_channels, kernel_size, groups=in_channels, padding=padding, bias=False),
                nn.Conv1d(in_channels, out_channels, kernel_size=1, bias=False),
                nn.GroupNorm(8, out_channels),  # More stable than BatchNorm for small batches
                nn.SiLU()  # Swish activation (better than ReLU)
            )

        self.conv1 = depthwise_separable_conv(input_channels, 32)
        self.conv2 = depthwise_separable_conv(32, 64)
        self.conv3 = depthwise_separable_conv(64, 128)

        # Adaptive pooling to ensure flexible sequence length compatibility
        self.global_pool = nn.AdaptiveAvgPool1d(1)

        # Fully connected layers
        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, num_classes)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.4)

        # Weight initialization
        self.apply(self.initialize_weights)

    def initialize_weights(self, m):
        if isinstance(m, nn.Conv1d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.Linear):
            nn.init.xavier_normal_(m.weight)
            if m.bias is not None:
                nn.init.zeros_(m.bias)

    def forward(self, x):
        x = self.conv1(x)
        x = F.max_pool1d(x, 2)

        x = self.conv2(x)
        x = F.max_pool1d(x, 2)

        x = self.conv3(x)
        x = F.max_pool1d(x, 2)

        # Global Average Pooling to reduce to fixed size
        x = self.global_pool(x)
        x = x.view(x.size(0), -1)

        # Fully connected layers
        x = F.silu(self.fc1(x))  # Swish activation
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %%
# Initialize model, optimizer with weight decay, and loss function
model = OptimizedCNNModel(num_classes=NUM_CLASSES, input_channels=3, seq_length=int(CHUNK_SIZE * 100))
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=1e-4)  # Weight decay helps reduce overfitting
criterion = nn.CrossEntropyLoss()

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, min_lr=1e-5)

# %%
def evaluate_model(loader, model, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():  # disable gradient calc
        for batch_X, batch_y in loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()

            _, predicted = torch.max(outputs, 1)  # get predicted class (max value)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    
    avg_loss = total_loss / len(loader)
    accuracy = 100 * correct / total
    return avg_loss, accuracy

# %%
# Training loop with validation
epochs = 100
for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    # Evaluate on training and testing sets
    train_loss, train_accuracy = evaluate_model(train_loader, model, criterion)
    test_loss, test_accuracy = evaluate_model(test_loader, model, criterion)
    
    # Logging the information
    logMsg = (f"Epoch [{epoch+1}/{epochs}], "
                   f"Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, "
                   f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
    
    logging.info(log_message)
    print(log_message)
    
    scheduler.step(train_loss)  # Adjust the learning rate if needed
# Save the model at the end of training
save_model(model, optimizer, "model.pth")
# Out:
# Epoch [1/100], Loss: 1.2863, Train Accuracy: 50.40%, Test Accuracy: 55.63%
# Epoch [2/100], Loss: 1.1152, Train Accuracy: 56.54%, Test Accuracy: 67.06%
# Epoch [3/100], Loss: 0.9933, Train Accuracy: 60.90%, Test Accuracy: 66.04%
# Epoch [4/100], Loss: 0.8885, Train Accuracy: 66.56%, Test Accuracy: 72.53%
# Epoch [5/100], Loss: 0.8209, Train Accuracy: 69.14%, Test Accuracy: 71.33%
# Epoch [6/100], Loss: 0.7563, Train Accuracy: 69.95%, Test Accuracy: 68.43%
# Epoch [7/100], Loss: 0.7308, Train Accuracy: 69.63%, Test Accuracy: 72.01%
# Epoch [8/100], Loss: 0.7027, Train Accuracy: 71.24%, Test Accuracy: 69.62%
# Epoch [9/100], Loss: 0.6910, Train Accuracy: 72.05%, Test Accuracy: 70.31%
# Epoch [10/100], Loss: 0.6871, Train Accuracy: 71.41%, Test Accuracy: 70.82%
# Epoch [11/100], Loss: 0.6562, Train Accuracy: 71.89%, Test Accuracy: 70.14%
# Epoch [12/100], Loss: 0.6352, Train Accuracy: 73.02%, Test Accuracy: 67.58%
# Epoch [13/100], Loss: 0.6188, Train Accuracy: 73.02%, Test Accuracy: 71.16%
# Epoch [14/100], Loss: 0.6185, Train Accuracy: 74.80%, Test Accuracy: 62.80%
# Epoch [15/100], Loss: 0.5806, Train Accuracy: 75.61%, Test Accuracy: 66.55%
# Epoch [16/100], Loss: 0.5730, Train Accuracy: 75.12%, Test Accuracy: 66.04%
# Epoch [17/100], Loss: 0.5639, Train Accuracy: 76.25%, Test Accuracy: 60.92%
# Epoch [18/100], Loss: 0.5540, Train Accuracy: 77.71%, Test Accuracy: 65.19%
# Epoch [19/100], Loss: 0.5515, Train Accuracy: 77.87%, Test Accuracy: 64.85%
# Epoch [20/100], Loss: 0.5447, Train Accuracy: 78.19%, Test Accuracy: 65.87%
# Epoch [21/100], Loss: 0.5361, Train Accuracy: 78.68%, Test Accuracy: 63.65%
# Epoch [22/100], Loss: 0.5098, Train Accuracy: 79.64%, Test Accuracy: 62.80%
# Epoch [23/100], Loss: 0.5151, Train Accuracy: 79.48%, Test Accuracy: 65.36%
# Epoch [24/100], Loss: 0.4804, Train Accuracy: 82.88%, Test Accuracy: 62.12%
# Epoch [25/100], Loss: 0.4620, Train Accuracy: 83.20%, Test Accuracy: 61.43%
# Epoch [26/100], Loss: 0.4757, Train Accuracy: 79.16%, Test Accuracy: 66.21%
# Epoch [27/100], Loss: 0.4713, Train Accuracy: 83.84%, Test Accuracy: 61.26%
# Epoch [28/100], Loss: 0.4353, Train Accuracy: 83.36%, Test Accuracy: 70.31%
# Epoch [29/100], Loss: 0.4463, Train Accuracy: 83.52%, Test Accuracy: 63.82%
# Epoch [30/100], Loss: 0.4191, Train Accuracy: 84.17%, Test Accuracy: 66.21%
# Epoch [31/100], Loss: 0.4154, Train Accuracy: 85.30%, Test Accuracy: 62.29%
# Epoch [32/100], Loss: 0.4124, Train Accuracy: 86.27%, Test Accuracy: 65.53%
# Epoch [33/100], Loss: 0.3745, Train Accuracy: 84.65%, Test Accuracy: 66.21%
# Epoch [34/100], Loss: 0.3923, Train Accuracy: 85.62%, Test Accuracy: 63.99%
# Epoch [35/100], Loss: 0.3678, Train Accuracy: 86.43%, Test Accuracy: 63.48%
# Epoch [36/100], Loss: 0.3588, Train Accuracy: 88.37%, Test Accuracy: 61.26%
# Epoch [37/100], Loss: 0.3508, Train Accuracy: 88.37%, Test Accuracy: 66.21%
# Epoch [38/100], Loss: 0.3443, Train Accuracy: 87.88%, Test Accuracy: 63.48%
# Epoch [39/100], Loss: 0.3361, Train Accuracy: 89.34%, Test Accuracy: 63.14%
# Epoch [40/100], Loss: 0.2924, Train Accuracy: 89.34%, Test Accuracy: 64.51%
# Epoch [41/100], Loss: 0.2995, Train Accuracy: 90.95%, Test Accuracy: 64.51%
# Epoch [42/100], Loss: 0.2821, Train Accuracy: 91.11%, Test Accuracy: 64.16%
# Epoch [43/100], Loss: 0.2760, Train Accuracy: 92.08%, Test Accuracy: 63.14%
# Epoch [44/100], Loss: 0.2645, Train Accuracy: 92.25%, Test Accuracy: 63.14%
# Epoch [45/100], Loss: 0.2579, Train Accuracy: 94.02%, Test Accuracy: 66.04%
# Epoch [46/100], Loss: 0.2487, Train Accuracy: 89.34%, Test Accuracy: 63.48%
# Epoch [47/100], Loss: 0.2640, Train Accuracy: 91.76%, Test Accuracy: 60.92%
# Epoch [48/100], Loss: 0.2343, Train Accuracy: 93.05%, Test Accuracy: 62.63%
# Epoch [49/100], Loss: 0.2262, Train Accuracy: 94.35%, Test Accuracy: 62.80%
# Epoch [50/100], Loss: 0.2226, Train Accuracy: 93.21%, Test Accuracy: 64.85%
# Epoch [51/100], Loss: 0.2084, Train Accuracy: 95.80%, Test Accuracy: 62.80%
# Epoch [52/100], Loss: 0.1992, Train Accuracy: 97.25%, Test Accuracy: 62.97%
# Epoch [53/100], Loss: 0.1926, Train Accuracy: 95.64%, Test Accuracy: 60.41%
# Epoch [54/100], Loss: 0.1765, Train Accuracy: 96.45%, Test Accuracy: 63.14%
# Epoch [55/100], Loss: 0.1700, Train Accuracy: 96.28%, Test Accuracy: 60.41%
# Epoch [56/100], Loss: 0.1601, Train Accuracy: 98.38%, Test Accuracy: 61.60%
# Epoch [57/100], Loss: 0.1487, Train Accuracy: 98.22%, Test Accuracy: 62.12%
# Epoch [58/100], Loss: 0.1360, Train Accuracy: 98.55%, Test Accuracy: 62.46%
# Epoch [59/100], Loss: 0.1262, Train Accuracy: 98.22%, Test Accuracy: 60.92%
# Epoch [60/100], Loss: 0.1255, Train Accuracy: 97.90%, Test Accuracy: 63.65%
# Epoch [61/100], Loss: 0.1261, Train Accuracy: 98.22%, Test Accuracy: 61.77%
# Epoch [62/100], Loss: 0.1161, Train Accuracy: 99.03%, Test Accuracy: 60.92%
# Epoch [63/100], Loss: 0.1052, Train Accuracy: 99.35%, Test Accuracy: 60.92%
# Epoch [64/100], Loss: 0.1007, Train Accuracy: 99.35%, Test Accuracy: 62.12%
# Epoch [65/100], Loss: 0.1048, Train Accuracy: 99.84%, Test Accuracy: 61.77%
# Epoch [66/100], Loss: 0.0856, Train Accuracy: 99.19%, Test Accuracy: 64.16%
# Epoch [67/100], Loss: 0.0860, Train Accuracy: 99.35%, Test Accuracy: 62.29%
# Epoch [68/100], Loss: 0.0914, Train Accuracy: 99.35%, Test Accuracy: 61.09%
# Epoch [69/100], Loss: 0.0855, Train Accuracy: 99.84%, Test Accuracy: 61.60%
# Epoch [70/100], Loss: 0.0719, Train Accuracy: 99.03%, Test Accuracy: 62.80%
# Epoch [71/100], Loss: 0.0705, Train Accuracy: 99.52%, Test Accuracy: 61.26%
# Epoch [72/100], Loss: 0.0720, Train Accuracy: 99.35%, Test Accuracy: 62.46%
# Epoch [73/100], Loss: 0.0673, Train Accuracy: 98.87%, Test Accuracy: 66.04%
# Epoch [74/100], Loss: 0.0755, Train Accuracy: 98.38%, Test Accuracy: 58.87%
# Epoch [75/100], Loss: 0.0883, Train Accuracy: 98.71%, Test Accuracy: 60.41%
# Epoch [76/100], Loss: 0.0924, Train Accuracy: 98.71%, Test Accuracy: 63.99%
# Epoch [77/100], Loss: 0.0640, Train Accuracy: 99.84%, Test Accuracy: 61.26%
# Epoch [78/100], Loss: 0.0541, Train Accuracy: 99.35%, Test Accuracy: 61.77%
# Epoch [79/100], Loss: 0.0571, Train Accuracy: 100.00%, Test Accuracy: 63.14%
# Epoch [80/100], Loss: 0.0496, Train Accuracy: 99.84%, Test Accuracy: 62.63%
# Epoch [81/100], Loss: 0.0516, Train Accuracy: 100.00%, Test Accuracy: 61.95%
# Epoch [82/100], Loss: 0.0396, Train Accuracy: 100.00%, Test Accuracy: 62.97%
# Epoch [83/100], Loss: 0.0544, Train Accuracy: 100.00%, Test Accuracy: 61.60%
# Epoch [84/100], Loss: 0.0433, Train Accuracy: 100.00%, Test Accuracy: 62.29%
# Epoch [85/100], Loss: 0.0456, Train Accuracy: 99.84%, Test Accuracy: 61.26%
# Epoch [86/100], Loss: 0.0537, Train Accuracy: 99.19%, Test Accuracy: 61.60%
# Epoch [87/100], Loss: 0.0367, Train Accuracy: 99.35%, Test Accuracy: 62.97%
# Epoch [88/100], Loss: 0.0336, Train Accuracy: 100.00%, Test Accuracy: 60.24%
# Epoch [89/100], Loss: 0.0290, Train Accuracy: 100.00%, Test Accuracy: 60.75%
# Epoch [90/100], Loss: 0.0238, Train Accuracy: 100.00%, Test Accuracy: 61.95%
# Epoch [91/100], Loss: 0.0310, Train Accuracy: 100.00%, Test Accuracy: 62.12%
# Epoch [92/100], Loss: 0.0251, Train Accuracy: 100.00%, Test Accuracy: 59.73%
# Epoch [93/100], Loss: 0.0331, Train Accuracy: 100.00%, Test Accuracy: 63.99%
# Epoch [94/100], Loss: 0.0244, Train Accuracy: 100.00%, Test Accuracy: 61.43%
# Epoch [95/100], Loss: 0.0251, Train Accuracy: 100.00%, Test Accuracy: 61.77%
# Epoch [96/100], Loss: 0.0220, Train Accuracy: 100.00%, Test Accuracy: 61.77%
# Epoch [97/100], Loss: 0.0279, Train Accuracy: 100.00%, Test Accuracy: 62.97%
# Epoch [98/100], Loss: 0.0293, Train Accuracy: 100.00%, Test Accuracy: 60.92%
# Epoch [99/100], Loss: 0.0259, Train Accuracy: 100.00%, Test Accuracy: 62.29%
# Epoch [100/100], Loss: 0.0313, Train Accuracy: 100.00%, Test Accuracy: 61.26%
# Model saved to model.pth

# %%
# Plot the loss graph
plt.plot(range(1, epochs + 1), losses, marker='o', linestyle='-', color='b')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
# Import necessary libraries
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Activities for the Confusion matrix
ACTIVITIES = ['sit', 'walk','upstair','downstair']

# Model evaluation (confusion matrix)
model.eval()
all_predictions = []
all_labels = []

# Loop through the test loader to collect predictions and true labels
with torch.no_grad():
    for batch_X, batch_y in test_loader:
        outputs = model(batch_X)
        _, predicted = torch.max(outputs, 1)
        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(batch_y.cpu().numpy())

# Compute the confusion matrix, explicitly specifying the labels
conf_matrix = confusion_matrix(all_labels, all_predictions, labels=[0, 1, 2,3]) 

# Assuming conf_matrix and ACTIVITIES are already defined
class_accuracies = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)  # Compute per-class accuracy

# Display the confusion matrix
disp = ConfusionMatrixDisplay(conf_matrix, display_labels=ACTIVITIES)
fig, ax = plt.subplots()
disp.plot(cmap=plt.cm.Blues, ax=ax)

# Add per-class accuracy text
for i, activity in enumerate(ACTIVITIES):
    acc_text = f"{class_accuracies[i] * 100:.2f}%"
    ax.text(
        len(ACTIVITIES) + 0.3, i, acc_text, 
        fontsize=12, verticalalignment='center', color='black'
    )

plt.title("Confusion Matrix for Activities with Per-Class Accuracy")
plt.show()

# %%
import torch.nn.functional as F

model.eval()  # Set model to evaluation mode
incorrect_samples = []

with torch.no_grad():  # Disable gradient computation
    for batch_X, batch_y in test_loader:
        outputs = model(batch_X)  # Get raw logits
        probabilities = F.softmax(outputs, dim=1)  # Convert to probabilities
        predicted_labels = torch.argmax(probabilities, dim=1)  # Get predicted class
        confidence_scores = torch.max(probabilities, dim=1).values  # Get max confidence

        # Find incorrect predictions
        incorrect_indices = (predicted_labels != batch_y)
        for i in range(len(batch_y)):
            if incorrect_indices[i]:
                incorrect_samples.append({
                    "True Label": batch_y[i].item(),
                    "Predicted Label": predicted_labels[i].item(),
                    "Confidence": confidence_scores[i].item(),
                    "Probabilities": probabilities[i].tolist()
                })

# Print results
for sample in incorrect_samples:
    print(f"True Label: {sample['True Label']}, Predicted: {sample['Predicted Label']}, Confidence: {sample['Confidence']:.4f}")
    print(f"Full Probabilities: {sample['Probabilities']}")
# Out:
# True Label: 1, Predicted: 3, Confidence: 0.9285
# Full Probabilities: [0.0002492967469152063, 0.010309473611414433, 0.06090905889868736, 0.9285321235656738]
# True Label: 1, Predicted: 3, Confidence: 0.9999
# Full Probabilities: [1.9073652310908074e-06, 5.470016913022846e-05, 2.8838226171501447e-06, 0.9999405145645142]
# True Label: 1, Predicted: 3, Confidence: 0.9843
# Full Probabilities: [3.885124533553608e-05, 0.015619052574038506, 4.4812645683123264e-06, 0.9843376278877258]
# True Label: 1, Predicted: 3, Confidence: 0.7635
# Full Probabilities: [9.747076546773314e-05, 0.23641911149024963, 4.549096502159955e-06, 0.7634788751602173]
# True Label: 2, Predicted: 3, Confidence: 0.5870
# Full Probabilities: [1.5796426851011347e-06, 5.6768276408547536e-06, 0.4130055606365204, 0.5869871973991394]
# True Label: 2, Predicted: 3, Confidence: 0.6464
# Full Probabilities: [4.3356554670026526e-05, 0.06664959341287613, 0.28694990277290344, 0.6463571786880493]
# True Label: 2, Predicted: 1, Confidence: 0.7000
# Full Probabilities: [5.631499516312033e-05, 0.7000138759613037, 0.006053731311112642, 0.2938760221004486]
# True Label: 2, Predicted: 3, Confidence: 0.5501
# Full Probabilities: [3.407812982914038e-05, 0.002736508147791028, 0.4470979869365692, 0.5501313805580139]
# True Label: 2, Predicted: 3, Confidence: 0.7043
# Full Probabilities: [7.678251563447702e-07, 1.5253165656758938e-05, 0.29568150639533997, 0.7043025493621826]
# True Label: 2, Predicted: 3, Confidence: 0.7058
# Full Probabilities: [2.001557277253596e-06, 2.1994885628373595e-06, 0.2941734194755554, 0.7058223485946655]
# True Label: 3, Predicted: 1, Confidence: 0.9785
# Full Probabilities: [2.0038683942402713e-05, 0.9784650802612305, 0.00010200501856161281, 0.02141280099749565]
# True Label: 3, Predicted: 1, Confidence: 0.9989
# Full Probabilities: [1.2972218428330962e-05, 0.9989498257637024, 0.0001811699039535597, 0.0008561357972212136]
# True Label: 3, Predicted: 1, Confidence: 0.9999
# Full Probabilities: [2.2269105102168396e-06, 0.9998713731765747, 4.074533990205964e-06, 0.00012226238322909921]
# True Label: 3, Predicted: 1, Confidence: 0.8941
# Full Probabilities: [0.0001370581885566935, 0.89405357837677, 0.009386137127876282, 0.09642315655946732]
# True Label: 3, Predicted: 2, Confidence: 0.9794
# Full Probabilities: [7.609048770973459e-05, 0.02043606899678707, 0.9793908596038818, 9.706556738819927e-05]
# True Label: 3, Predicted: 1, Confidence: 0.9874
# Full Probabilities: [0.00016540517390239984, 0.9873970150947571, 0.003138352418318391, 0.009299269877374172]
# True Label: 3, Predicted: 1, Confidence: 0.9617
# Full Probabilities: [0.00026835029711946845, 0.9617113471031189, 0.02408658154308796, 0.01393373217433691]
# True Label: 0, Predicted: 3, Confidence: 0.9989
# Full Probabilities: [0.0003256011405028403, 0.0007904912927187979, 8.511006853950676e-06, 0.9988754391670227]
# True Label: 0, Predicted: 3, Confidence: 0.9988
# Full Probabilities: [0.0007179175736382604, 0.00044376440928317606, 5.003571459383238e-06, 0.9988333582878113]
# True Label: 0, Predicted: 3, Confidence: 0.9990
# Full Probabilities: [0.0007118131034076214, 0.0003136562881991267, 4.5790702642989345e-06, 0.9989699125289917]
# True Label: 0, Predicted: 3, Confidence: 0.9985
# Full Probabilities: [0.0009936123387888074, 0.0005481038242578506, 2.773206688289065e-06, 0.9984555244445801]
# True Label: 0, Predicted: 3, Confidence: 0.9989
# Full Probabilities: [0.0006357731763273478, 0.00048439542297273874, 2.236006594102946e-06, 0.9988775849342346]
# True Label: 0, Predicted: 3, Confidence: 0.9976
# Full Probabilities: [0.001559342839755118, 0.0008057329687289894, 2.715802111197263e-06, 0.9976321458816528]
# True Label: 0, Predicted: 3, Confidence: 0.9981
# Full Probabilities: [0.001103086513467133, 0.0007776874699629843, 5.651597803080222e-06, 0.9981136322021484]
# True Label: 0, Predicted: 3, Confidence: 0.9974
# Full Probabilities: [0.0009214575402438641, 0.001635521068237722, 5.9429771681607235e-06, 0.9974370002746582]
# True Label: 0, Predicted: 3, Confidence: 0.9988
# Full Probabilities: [0.0006304542766883969, 0.0005965683376416564, 2.2979925233812537e-06, 0.9987706542015076]
# True Label: 0, Predicted: 3, Confidence: 0.9992
# Full Probabilities: [0.00036125234328210354, 0.0004112259775865823, 3.122657744825119e-06, 0.9992244243621826]
# True Label: 0, Predicted: 3, Confidence: 0.9992
# Full Probabilities: [0.00040509822429157794, 0.00038921242230571806, 2.3728098312858492e-06, 0.9992033839225769]
# True Label: 0, Predicted: 3, Confidence: 0.9992
# Full Probabilities: [0.00043313074274919927, 0.00032520160311833024, 2.737884187808959e-06, 0.9992389678955078]
# True Label: 0, Predicted: 3, Confidence: 0.9997
# Full Probabilities: [0.0001602228730916977, 0.00018106211791746318, 4.662784704123624e-06, 0.9996540546417236]
# True Label: 0, Predicted: 3, Confidence: 0.9994
# Full Probabilities: [0.0003063927579205483, 0.0003147016395814717, 6.163650596135994e-06, 0.9993727803230286]
# True Label: 0, Predicted: 3, Confidence: 0.9993
# Full Probabilities: [0.00036049188929609954, 0.000372302602045238, 3.706158395289094e-06, 0.9992634654045105]
# True Label: 0, Predicted: 3, Confidence: 0.9956
# Full Probabilities: [0.000769542995840311, 0.0036136906128376722, 2.8005859348922968e-05, 0.9955887794494629]
# True Label: 0, Predicted: 3, Confidence: 0.9968
# Full Probabilities: [0.0004148889274802059, 0.0027499767020344734, 1.6996231352095492e-05, 0.9968180656433105]
# True Label: 0, Predicted: 3, Confidence: 0.9959
# Full Probabilities: [0.0008013407932594419, 0.003263479797169566, 2.1857831598026678e-05, 0.9959133267402649]
# True Label: 0, Predicted: 3, Confidence: 0.9979
# Full Probabilities: [0.0004880809283349663, 0.0016201440012082458, 1.5922749298624694e-05, 0.9978758096694946]
# True Label: 0, Predicted: 3, Confidence: 0.9981
# Full Probabilities: [0.0004669547197408974, 0.0013911779969930649, 1.0445746738696471e-05, 0.9981314539909363]
# True Label: 0, Predicted: 3, Confidence: 0.9958
# Full Probabilities: [0.0008316101739183068, 0.003306485014036298, 1.977085594262462e-05, 0.9958421587944031]
# True Label: 0, Predicted: 3, Confidence: 0.9970
# Full Probabilities: [0.0006621012580581009, 0.0023021255619823933, 1.188515034300508e-05, 0.99702388048172]
# True Label: 0, Predicted: 3, Confidence: 0.9965
# Full Probabilities: [0.0008471698383800685, 0.0026546833105385303, 1.3876454431738239e-05, 0.9964842796325684]
# True Label: 0, Predicted: 3, Confidence: 0.9935
# Full Probabilities: [0.0008672308758832514, 0.005614548455923796, 2.3513279302278534e-05, 0.9934946894645691]
# True Label: 0, Predicted: 3, Confidence: 0.9892
# Full Probabilities: [0.0013996802736073732, 0.00939950067549944, 3.5662313166540116e-05, 0.9891651272773743]
# True Label: 0, Predicted: 3, Confidence: 0.9921
# Full Probabilities: [0.0014422460226342082, 0.006432106718420982, 2.7133224648423493e-05, 0.9920985698699951]
# True Label: 0, Predicted: 3, Confidence: 0.9922
# Full Probabilities: [0.0015517531428486109, 0.006200511008501053, 2.552186924731359e-05, 0.992222249507904]
# True Label: 0, Predicted: 3, Confidence: 0.9971
# Full Probabilities: [0.0004861617926508188, 0.0023452306631952524, 2.1534542611334473e-05, 0.9971470236778259]
# True Label: 0, Predicted: 3, Confidence: 0.9952
# Full Probabilities: [0.0007040135096758604, 0.004050701856613159, 2.6663656171876937e-05, 0.9952185750007629]
# True Label: 0, Predicted: 3, Confidence: 0.9928
# Full Probabilities: [0.001047174446284771, 0.006104579661041498, 2.7514419343788177e-05, 0.992820680141449]
# True Label: 1, Predicted: 2, Confidence: 0.9051
# Full Probabilities: [0.00030107941711321473, 0.094368577003479, 0.9051276445388794, 0.0002027231821557507]
# True Label: 1, Predicted: 3, Confidence: 0.9645
# Full Probabilities: [3.101885522482917e-05, 0.03470398485660553, 0.0008011794416233897, 0.9644637703895569]
# True Label: 1, Predicted: 3, Confidence: 0.8155
# Full Probabilities: [0.00026569506735540926, 0.1841813325881958, 6.237276102183387e-05, 0.8154905438423157]
# True Label: 1, Predicted: 2, Confidence: 0.5012
# Full Probabilities: [0.03859025239944458, 0.4160218834877014, 0.5011925101280212, 0.04419543594121933]
# True Label: 1, Predicted: 2, Confidence: 0.9458
# Full Probabilities: [2.1384750652941875e-05, 0.02851281873881817, 0.9458189010620117, 0.02564685232937336]
# True Label: 1, Predicted: 3, Confidence: 0.9610
# Full Probabilities: [2.6583105864119716e-05, 0.03899238631129265, 2.721228611335391e-07, 0.9609807729721069]
# True Label: 1, Predicted: 3, Confidence: 0.9126
# Full Probabilities: [2.51850960921729e-05, 0.08742282539606094, 4.1777494175221364e-07, 0.9125515222549438]
# True Label: 1, Predicted: 3, Confidence: 0.9002
# Full Probabilities: [2.839545595634263e-05, 0.0997631773352623, 2.1349749204091495e-06, 0.9002062678337097]
# True Label: 1, Predicted: 3, Confidence: 0.9916
# Full Probabilities: [8.977237484941725e-06, 0.008362142369151115, 4.4888241745866253e-07, 0.9916284084320068]
# True Label: 1, Predicted: 3, Confidence: 0.9827
# Full Probabilities: [1.3482332178682555e-05, 0.017272228375077248, 1.882597473468195e-07, 0.9827141165733337]
# True Label: 1, Predicted: 3, Confidence: 0.7498
# Full Probabilities: [4.128873843001202e-05, 0.25013935565948486, 3.8661579537802027e-07, 0.7498189806938171]
# True Label: 1, Predicted: 3, Confidence: 0.9999
# Full Probabilities: [9.952002528734738e-07, 0.00012165724183432758, 1.278965271467314e-07, 0.9998772144317627]
# True Label: 1, Predicted: 3, Confidence: 0.9921
# Full Probabilities: [6.00288240093505e-06, 0.007909570820629597, 9.034722125988992e-08, 0.9920843839645386]
# True Label: 1, Predicted: 3, Confidence: 0.9958
# Full Probabilities: [5.211288680584403e-06, 0.00422105984762311, 1.56119412508815e-07, 0.9957736134529114]
# True Label: 1, Predicted: 3, Confidence: 0.9994
# Full Probabilities: [2.169975005017477e-06, 0.0006149490945972502, 2.025589509457859e-07, 0.9993826150894165]
# True Label: 2, Predicted: 3, Confidence: 0.9445
# Full Probabilities: [0.00032089176238514483, 1.1989242921117693e-05, 0.055158451199531555, 0.9445086121559143]
# True Label: 2, Predicted: 3, Confidence: 0.9980
# Full Probabilities: [1.1359200868810149e-07, 4.789503904589765e-09, 0.0019545669201761484, 0.9980453252792358]
# True Label: 2, Predicted: 3, Confidence: 0.9455
# Full Probabilities: [1.1727853177490033e-07, 2.4132097209417225e-08, 0.054522428661584854, 0.9454774856567383]
# True Label: 2, Predicted: 1, Confidence: 0.5188
# Full Probabilities: [1.6627132936264388e-05, 0.5188149213790894, 0.4808748662471771, 0.0002935815427917987]
# True Label: 2, Predicted: 1, Confidence: 0.5508
# Full Probabilities: [0.0005672126426361501, 0.550786554813385, 0.018206069245934486, 0.43044012784957886]
# True Label: 2, Predicted: 3, Confidence: 0.8753
# Full Probabilities: [6.608407602470834e-06, 0.0006975258584134281, 0.12402056157588959, 0.8752753138542175]
# True Label: 2, Predicted: 3, Confidence: 0.7249
# Full Probabilities: [0.014901652932167053, 0.11878252029418945, 0.14137209951877594, 0.7249436974525452]
# True Label: 2, Predicted: 3, Confidence: 0.8862
# Full Probabilities: [1.1376259863027371e-06, 8.833811762087862e-07, 0.1138109564781189, 0.8861870169639587]
# True Label: 3, Predicted: 2, Confidence: 0.9992
# Full Probabilities: [8.093144060694613e-06, 0.0001561364479130134, 0.9991819262504578, 0.0006537657463923097]
# True Label: 3, Predicted: 2, Confidence: 0.7682
# Full Probabilities: [9.503398359811399e-06, 9.201664215652272e-05, 0.7681573033332825, 0.23174114525318146]
# True Label: 3, Predicted: 2, Confidence: 0.9228
# Full Probabilities: [2.2005726350471377e-05, 0.004869612865149975, 0.9228321313858032, 0.07227619737386703]
# True Label: 3, Predicted: 2, Confidence: 0.5887
# Full Probabilities: [1.1819995052064769e-05, 5.05713360325899e-05, 0.588681161403656, 0.4112564027309418]
# True Label: 3, Predicted: 1, Confidence: 0.5806
# Full Probabilities: [0.003242991166189313, 0.5806334018707275, 0.19098210334777832, 0.22514143586158752]
# True Label: 3, Predicted: 2, Confidence: 0.9550
# Full Probabilities: [1.2575728192132374e-07, 1.8313566840788553e-07, 0.9549932479858398, 0.045006394386291504]
# True Label: 3, Predicted: 2, Confidence: 0.8367
# Full Probabilities: [0.0008641194435767829, 0.02573530562222004, 0.8367102742195129, 0.13669025897979736]
# True Label: 3, Predicted: 2, Confidence: 0.9883
# Full Probabilities: [2.0291119653848e-05, 0.004259399604052305, 0.9882838726043701, 0.007436506450176239]
# True Label: 3, Predicted: 2, Confidence: 0.5120
# Full Probabilities: [4.195522251393413e-06, 1.13599867290759e-07, 0.5119925737380981, 0.48800307512283325]
# True Label: 3, Predicted: 2, Confidence: 0.7166
# Full Probabilities: [6.512530489999335e-06, 0.00038262654561549425, 0.7166111469268799, 0.282999724149704]
# True Label: 3, Predicted: 2, Confidence: 0.8998
# Full Probabilities: [1.5644112636437058e-06, 9.843695443123579e-05, 0.899826169013977, 0.10007378458976746]
# True Label: 3, Predicted: 2, Confidence: 0.9833
# Full Probabilities: [1.197210713144159e-05, 0.01510531734675169, 0.983252763748169, 0.0016300119459629059]
# True Label: 3, Predicted: 2, Confidence: 0.8966
# Full Probabilities: [0.003629575949162245, 0.00013495964230969548, 0.8966481685638428, 0.09958729147911072]
# True Label: 3, Predicted: 2, Confidence: 0.9807
# Full Probabilities: [3.162613938911818e-05, 0.018930533900856972, 0.9807227253913879, 0.0003150658158119768]
# True Label: 3, Predicted: 2, Confidence: 0.7208
# Full Probabilities: [0.00017825045506469905, 0.27812260389328003, 0.7208456993103027, 0.000853502016980201]
# True Label: 3, Predicted: 2, Confidence: 0.6357
# Full Probabilities: [0.0008440779056400061, 0.3217695951461792, 0.6356768608093262, 0.041709404438734055]
# True Label: 3, Predicted: 2, Confidence: 0.6811
# Full Probabilities: [0.000560217653401196, 0.05388693884015083, 0.6810700297355652, 0.2644828259944916]
# True Label: 0, Predicted: 1, Confidence: 0.9599
# Full Probabilities: [0.03838295489549637, 0.9598500728607178, 4.9557225878515965e-08, 0.0017669267253950238]
# True Label: 0, Predicted: 1, Confidence: 0.9774
# Full Probabilities: [0.02238803170621395, 0.9773625731468201, 1.1588641513071707e-07, 0.0002493474748916924]
# True Label: 0, Predicted: 1, Confidence: 0.8804
# Full Probabilities: [0.11811358481645584, 0.880413293838501, 2.332463111542893e-08, 0.0014731392730027437]
# True Label: 0, Predicted: 1, Confidence: 0.8927
# Full Probabilities: [0.10619716346263885, 0.8927049040794373, 2.01159906509929e-08, 0.0010978786740452051]
# True Label: 0, Predicted: 1, Confidence: 0.8642
# Full Probabilities: [0.1347673237323761, 0.8641727566719055, 1.5209399961690906e-08, 0.0010598981752991676]
# True Label: 0, Predicted: 1, Confidence: 0.8866
# Full Probabilities: [0.11270437389612198, 0.886597216129303, 2.0889077134711442e-08, 0.0006984049105085433]
# True Label: 0, Predicted: 1, Confidence: 0.9006
# Full Probabilities: [0.09873174875974655, 0.9006417393684387, 1.8873514306960715e-08, 0.0006264517433010042]
# True Label: 0, Predicted: 1, Confidence: 0.8801
# Full Probabilities: [0.11901625990867615, 0.8801335096359253, 1.8348556451996956e-08, 0.0008501219563186169]
# True Label: 0, Predicted: 1, Confidence: 0.8895
# Full Probabilities: [0.10958746820688248, 0.8895309567451477, 1.5265790409557667e-08, 0.0008815061300992966]
# True Label: 0, Predicted: 1, Confidence: 0.8737
# Full Probabilities: [0.1253487914800644, 0.8737251162528992, 1.988929199114864e-08, 0.0009260798105970025]
# True Label: 0, Predicted: 1, Confidence: 0.8885
# Full Probabilities: [0.11096591502428055, 0.888462483882904, 2.1064314736918277e-08, 0.0005715882871299982]
# True Label: 0, Predicted: 1, Confidence: 0.9103
# Full Probabilities: [0.0890730768442154, 0.9102903604507446, 2.1582319931212623e-08, 0.0006365160807035863]
# True Label: 0, Predicted: 1, Confidence: 0.8503
# Full Probabilities: [0.14847584068775177, 0.8503080010414124, 1.8054072015161182e-08, 0.0012161985505372286]
# True Label: 0, Predicted: 1, Confidence: 0.8858
# Full Probabilities: [0.11321736127138138, 0.8857954740524292, 1.714130348773324e-08, 0.0009871829533949494]
# True Label: 0, Predicted: 1, Confidence: 0.8742
# Full Probabilities: [0.12467031925916672, 0.8742069005966187, 2.225244344344901e-08, 0.0011227559298276901]
# True Label: 2, Predicted: 3, Confidence: 0.7185
# Full Probabilities: [1.343212352367118e-05, 5.485464498633519e-05, 0.2814207077026367, 0.7185109853744507]
# True Label: 2, Predicted: 3, Confidence: 0.9999
# Full Probabilities: [1.5667400248275953e-06, 4.5227276132209226e-05, 3.941361683246214e-06, 0.9999492168426514]
# True Label: 2, Predicted: 3, Confidence: 0.9988
# Full Probabilities: [1.6655633316986496e-06, 1.5164990145422053e-05, 0.0011551681673154235, 0.9988279938697815]
# True Label: 2, Predicted: 3, Confidence: 0.9726
# Full Probabilities: [3.4238637454109266e-06, 7.1723716246197e-06, 0.027395250275731087, 0.972594141960144]
# True Label: 2, Predicted: 3, Confidence: 0.9996
# Full Probabilities: [3.520382506394526e-06, 1.3913959264755249e-05, 0.0003475479024928063, 0.9996349811553955]
# True Label: 2, Predicted: 3, Confidence: 0.8829
# Full Probabilities: [0.0004394355055410415, 0.10476641356945038, 0.011855353601276875, 0.882938802242279]
# True Label: 2, Predicted: 3, Confidence: 0.9818
# Full Probabilities: [1.7262966139242053e-05, 5.591824810835533e-05, 0.0181021299213171, 0.9818246960639954]
# True Label: 2, Predicted: 3, Confidence: 0.9527
# Full Probabilities: [1.3432120795187075e-05, 0.0010314476676285267, 0.046225663274526596, 0.9527295231819153]
# True Label: 2, Predicted: 3, Confidence: 0.9986
# Full Probabilities: [1.3692156244360376e-05, 0.0003103413328062743, 0.001079576788470149, 0.9985963702201843]
# True Label: 2, Predicted: 3, Confidence: 0.7203
# Full Probabilities: [6.373082578647882e-05, 0.0026962952688336372, 0.27692660689353943, 0.7203133702278137]
# True Label: 2, Predicted: 3, Confidence: 0.7565
# Full Probabilities: [0.0017045006388798356, 0.16967670619487762, 0.07215990126132965, 0.7564588785171509]
# True Label: 2, Predicted: 3, Confidence: 0.8749
# Full Probabilities: [6.760990072507411e-05, 0.004680718760937452, 0.1203644648194313, 0.8748871684074402]
# True Label: 2, Predicted: 3, Confidence: 0.5323
# Full Probabilities: [1.6288557162624784e-05, 0.0001453502627555281, 0.4675799608230591, 0.5322584509849548]
# True Label: 2, Predicted: 1, Confidence: 0.9018
# Full Probabilities: [0.0002678039309103042, 0.9017828702926636, 0.028624065220355988, 0.06932524591684341]
# True Label: 2, Predicted: 3, Confidence: 0.7544
# Full Probabilities: [6.492995453299955e-05, 0.0030365698039531708, 0.24247276782989502, 0.7544257044792175]
# True Label: 2, Predicted: 3, Confidence: 0.9978
# Full Probabilities: [1.0698249752749689e-05, 0.00016738229896873236, 0.0019746008329093456, 0.997847318649292]
# True Label: 2, Predicted: 1, Confidence: 0.8551
# Full Probabilities: [0.00028650782769545913, 0.8550766706466675, 0.14432236552238464, 0.0003144407528452575]
# True Label: 2, Predicted: 1, Confidence: 0.9263
# Full Probabilities: [0.004547255113720894, 0.9262702465057373, 0.012682478874921799, 0.05650003254413605]
# True Label: 2, Predicted: 1, Confidence: 0.7990
# Full Probabilities: [0.00014658500731457025, 0.7989894151687622, 0.1855170726776123, 0.015346981585025787]
# True Label: 2, Predicted: 3, Confidence: 0.9984
# Full Probabilities: [1.2124020031478722e-05, 0.00033821447868831456, 0.0012732933973893523, 0.9983763694763184]
# True Label: 2, Predicted: 3, Confidence: 0.9851
# Full Probabilities: [3.8542224501725286e-05, 0.0005485232104547322, 0.01429544948041439, 0.9851174354553223]
# True Label: 2, Predicted: 3, Confidence: 0.9997
# Full Probabilities: [6.604978466384637e-07, 6.318944656413805e-07, 0.00029975338838994503, 0.9996989965438843]
# True Label: 2, Predicted: 3, Confidence: 0.8647
# Full Probabilities: [3.2776713396742707e-06, 7.934459063108079e-06, 0.13525253534317017, 0.8647361993789673]
# True Label: 2, Predicted: 3, Confidence: 0.9588
# Full Probabilities: [0.0001680937421042472, 0.011044125072658062, 0.029995767399668694, 0.9587920904159546]
# True Label: 2, Predicted: 1, Confidence: 0.7601
# Full Probabilities: [0.0011213487014174461, 0.7601102590560913, 0.15692609548568726, 0.08184231072664261]
# True Label: 2, Predicted: 3, Confidence: 0.9982
# Full Probabilities: [1.251448156835977e-05, 0.0003560642362572253, 0.0014790564309805632, 0.9981523156166077]
# True Label: 3, Predicted: 2, Confidence: 0.9935
# Full Probabilities: [2.012309550991631e-06, 0.006234582047909498, 0.9935243129730225, 0.0002391518937656656]
# True Label: 3, Predicted: 2, Confidence: 1.0000
# Full Probabilities: [1.5225428029452814e-08, 1.3584151474788086e-06, 0.9999567270278931, 4.1804025386227295e-05]
# True Label: 3, Predicted: 1, Confidence: 0.9215
# Full Probabilities: [0.00010863295756280422, 0.921473503112793, 0.005829428788274527, 0.07258844375610352]
# True Label: 3, Predicted: 2, Confidence: 0.9895
# Full Probabilities: [1.0142395694856532e-05, 0.008619635365903378, 0.9894508719444275, 0.001919363858178258]
# True Label: 3, Predicted: 2, Confidence: 0.9470
# Full Probabilities: [2.3201730073196813e-05, 0.008742349222302437, 0.9470356702804565, 0.044198811054229736]
# True Label: 3, Predicted: 2, Confidence: 0.9922
# Full Probabilities: [3.132608753730892e-06, 0.007014750968664885, 0.9921532273292542, 0.0008288963581435382]
# True Label: 3, Predicted: 2, Confidence: 0.9906
# Full Probabilities: [7.5202597145107575e-06, 0.008902685716748238, 0.9906208515167236, 0.0004689726047217846]
# True Label: 3, Predicted: 2, Confidence: 0.9979
# Full Probabilities: [1.3692829270439688e-06, 0.0015083826147019863, 0.9978500604629517, 0.000640191079583019]
# True Label: 3, Predicted: 2, Confidence: 0.8114
# Full Probabilities: [0.00014688547526020557, 0.09120843559503555, 0.8113784193992615, 0.09726624190807343]
# True Label: 3, Predicted: 2, Confidence: 0.9785
# Full Probabilities: [1.0804429848576547e-06, 2.9575976441265084e-05, 0.9785121083259583, 0.021457290276885033]
# True Label: 3, Predicted: 1, Confidence: 0.9801
# Full Probabilities: [0.00047957271453924477, 0.9801396131515503, 0.01909290812909603, 0.00028800484142266214]
# True Label: 3, Predicted: 2, Confidence: 0.8134
# Full Probabilities: [9.600580597179942e-06, 0.0011602930026128888, 0.8133859634399414, 0.1854441612958908]
# True Label: 3, Predicted: 2, Confidence: 0.9224
# Full Probabilities: [0.00014508144522551447, 0.011854670941829681, 0.9224418997764587, 0.06555837392807007]
# True Label: 3, Predicted: 2, Confidence: 0.9985
# Full Probabilities: [1.0173657756240573e-06, 1.071119277185062e-05, 0.9984716773033142, 0.0015164859360083938]
# True Label: 3, Predicted: 2, Confidence: 0.9043
# Full Probabilities: [7.82739880378358e-06, 0.09500586986541748, 0.9042762517929077, 0.0007100219372659922]
# True Label: 3, Predicted: 2, Confidence: 0.9923
# Full Probabilities: [4.6052768993831705e-06, 0.003290030173957348, 0.9923006296157837, 0.004404699429869652]
# True Label: 3, Predicted: 2, Confidence: 0.9841
# Full Probabilities: [5.2665611292468384e-05, 0.0009959818562492728, 0.9840865731239319, 0.014864804223179817]
# True Label: 3, Predicted: 1, Confidence: 0.5285
# Full Probabilities: [0.000742308038752526, 0.528484582901001, 0.39888888597488403, 0.07188411056995392]
# True Label: 0, Predicted: 1, Confidence: 0.9169
# Full Probabilities: [0.08299132436513901, 0.9168926477432251, 0.00011473153426777571, 1.1965137218794553e-06]
# True Label: 1, Predicted: 2, Confidence: 0.9991
# Full Probabilities: [1.7965361109872902e-07, 0.0009102753829210997, 0.9990895986557007, 1.9108632898223732e-08]
# True Label: 1, Predicted: 2, Confidence: 0.8390
# Full Probabilities: [0.00013558691716752946, 0.15794482827186584, 0.8389993906021118, 0.002920161234214902]
# True Label: 1, Predicted: 2, Confidence: 0.9985
# Full Probabilities: [1.1994784472335596e-06, 0.0014614179963245988, 0.998451828956604, 8.555927342968062e-05]
# True Label: 1, Predicted: 2, Confidence: 0.9939
# Full Probabilities: [8.921430708141997e-05, 0.005021606106311083, 0.9939126372337341, 0.0009765535360202193]
# True Label: 1, Predicted: 3, Confidence: 0.8692
# Full Probabilities: [0.0001174014323623851, 0.012032946571707726, 0.11866166442632675, 0.8691880106925964]
# True Label: 1, Predicted: 2, Confidence: 0.8836
# Full Probabilities: [5.4158608691068366e-05, 0.11192703992128372, 0.8835862278938293, 0.0044325473718345165]
# True Label: 1, Predicted: 3, Confidence: 0.9966
# Full Probabilities: [6.676292287011165e-06, 0.0002406621351838112, 0.003188901813700795, 0.996563732624054]
# True Label: 1, Predicted: 3, Confidence: 0.9931
# Full Probabilities: [7.579552038805559e-05, 0.004227129742503166, 0.00259386096149683, 0.9931032657623291]
# True Label: 1, Predicted: 3, Confidence: 0.5308
# Full Probabilities: [0.0004945624386891723, 0.24901233613491058, 0.2196929007768631, 0.5308001637458801]
# True Label: 1, Predicted: 3, Confidence: 0.8650
# Full Probabilities: [0.0005614854162558913, 0.08777394890785217, 0.046646300703287125, 0.8650182485580444]
# True Label: 1, Predicted: 2, Confidence: 0.9990
# Full Probabilities: [6.060124633222586e-07, 7.611110049765557e-05, 0.9990476965904236, 0.0008755794260650873]
# True Label: 1, Predicted: 2, Confidence: 0.9986
# Full Probabilities: [8.417587196163367e-06, 0.00013563109678216279, 0.9986162185668945, 0.0012396940728649497]
# True Label: 1, Predicted: 2, Confidence: 0.5593
# Full Probabilities: [4.909392009722069e-05, 0.006468034349381924, 0.5593351125717163, 0.43414774537086487]
# True Label: 1, Predicted: 2, Confidence: 0.9999
# Full Probabilities: [8.071369279605278e-07, 9.383601718582213e-05, 0.9999048709869385, 4.3814063133140735e-07]
# True Label: 1, Predicted: 2, Confidence: 0.6976
# Full Probabilities: [0.00020488028530962765, 0.006999018136411905, 0.6976168155670166, 0.29517924785614014]
# True Label: 1, Predicted: 2, Confidence: 0.9923
# Full Probabilities: [1.8463416040503944e-07, 8.025080688867092e-08, 0.9922945499420166, 0.007705227937549353]
# True Label: 1, Predicted: 2, Confidence: 0.9961
# Full Probabilities: [3.319712413940579e-05, 0.0023679120931774378, 0.9960881471633911, 0.001510820584371686]
# True Label: 1, Predicted: 2, Confidence: 0.9944
# Full Probabilities: [7.993786311999429e-06, 0.0013904061634093523, 0.9944384098052979, 0.0041632819920778275]
# True Label: 1, Predicted: 2, Confidence: 0.9999
# Full Probabilities: [8.642480793241702e-07, 6.572739948751405e-05, 0.9998767375946045, 5.6657372624613345e-05]
# True Label: 1, Predicted: 3, Confidence: 0.9435
# Full Probabilities: [0.00014554071822203696, 0.05267045646905899, 0.0036860976833850145, 0.9434979557991028]
# True Label: 1, Predicted: 2, Confidence: 0.7329
# Full Probabilities: [0.0003622793301474303, 0.21697567403316498, 0.7329416275024414, 0.04972038045525551]
# True Label: 1, Predicted: 2, Confidence: 0.8783
# Full Probabilities: [0.0007677070097997785, 0.010007679462432861, 0.8783172965049744, 0.11090737581253052]
# True Label: 1, Predicted: 2, Confidence: 0.8955
# Full Probabilities: [0.00022235697542782873, 0.10374549776315689, 0.8954695463180542, 0.0005626605125144124]
# True Label: 1, Predicted: 2, Confidence: 0.8674
# Full Probabilities: [7.250547696457943e-06, 4.217939203954302e-05, 0.8673704266548157, 0.13258017599582672]
# True Label: 1, Predicted: 3, Confidence: 0.5068
# Full Probabilities: [0.00013107781705912203, 0.038288410753011703, 0.4548053741455078, 0.5067752003669739]
# True Label: 1, Predicted: 3, Confidence: 0.9715
# Full Probabilities: [6.714408755215118e-06, 0.005443344358354807, 0.023040056228637695, 0.9715098738670349]
# True Label: 1, Predicted: 3, Confidence: 0.9614
# Full Probabilities: [0.001101092086173594, 0.021738911047577858, 0.01571231335401535, 0.9614477157592773]
# True Label: 1, Predicted: 3, Confidence: 0.9646
# Full Probabilities: [0.0001750368537614122, 0.03518718108534813, 5.5127082305261865e-05, 0.9645826816558838]
# True Label: 1, Predicted: 3, Confidence: 0.7873
# Full Probabilities: [0.0036107657942920923, 0.19800639152526855, 0.011111519299447536, 0.7872713208198547]
# True Label: 1, Predicted: 3, Confidence: 0.6694
# Full Probabilities: [0.0008285098010674119, 0.31637322902679443, 0.013441598042845726, 0.669356644153595]
# True Label: 1, Predicted: 3, Confidence: 0.9713
# Full Probabilities: [4.5021453843219206e-05, 0.00029022261151112616, 0.028364405035972595, 0.9713003039360046]
# True Label: 1, Predicted: 2, Confidence: 0.8213
# Full Probabilities: [6.237402430997463e-06, 0.17867767810821533, 0.8213159441947937, 1.377451468442814e-07]
# True Label: 1, Predicted: 3, Confidence: 0.9304
# Full Probabilities: [6.738823867635801e-05, 0.006742758210748434, 0.06279567629098892, 0.930394172668457]
# True Label: 1, Predicted: 3, Confidence: 0.9933
# Full Probabilities: [1.9657783923321404e-05, 0.0013597233919426799, 0.0053433943539857864, 0.9932772517204285]
# True Label: 1, Predicted: 2, Confidence: 0.8993
# Full Probabilities: [2.8779211788787507e-05, 0.0001118082509492524, 0.8993029594421387, 0.10055649280548096]
# True Label: 1, Predicted: 3, Confidence: 1.0000
# Full Probabilities: [3.037909209524514e-06, 4.1382107156096026e-05, 4.75153200341083e-07, 0.9999550580978394]
# True Label: 2, Predicted: 1, Confidence: 0.9968
# Full Probabilities: [0.0013184600975364447, 0.9967613816261292, 0.0019184568664059043, 1.7608475673114299e-06]
# True Label: 2, Predicted: 3, Confidence: 0.7674
# Full Probabilities: [2.6175780476478394e-06, 3.4547383620520122e-06, 0.23261117935180664, 0.7673826813697815]
# True Label: 2, Predicted: 3, Confidence: 0.5699
# Full Probabilities: [6.697922071907669e-05, 0.005308099556714296, 0.4247617721557617, 0.5698630809783936]
# True Label: 2, Predicted: 1, Confidence: 0.9906
# Full Probabilities: [0.00012474438699427992, 0.9906122088432312, 0.00881237629801035, 0.0004507718840613961]
# True Label: 2, Predicted: 3, Confidence: 0.8575
# Full Probabilities: [0.00022128812270238996, 0.00012737805081997067, 0.14213162660598755, 0.8575197458267212]
# True Label: 2, Predicted: 1, Confidence: 0.8094
# Full Probabilities: [8.613158570369706e-05, 0.8093907833099365, 0.0040937927551567554, 0.1864292472600937]
# True Label: 2, Predicted: 3, Confidence: 0.9853
# Full Probabilities: [1.3113652130414266e-05, 0.00048204860650002956, 0.014190440997481346, 0.9853143692016602]
# True Label: 2, Predicted: 3, Confidence: 0.9886
# Full Probabilities: [5.6200129620265216e-05, 0.01112024299800396, 0.00019380587036721408, 0.9886296987533569]
# True Label: 2, Predicted: 3, Confidence: 0.5381
# Full Probabilities: [1.7418926290702075e-05, 0.0002367310517001897, 0.461689829826355, 0.538055956363678]
# True Label: 2, Predicted: 3, Confidence: 0.9166
# Full Probabilities: [0.00021887439652346075, 0.08195343613624573, 0.001198587822727859, 0.9166290760040283]
# True Label: 2, Predicted: 1, Confidence: 0.9995
# Full Probabilities: [7.094416650943458e-05, 0.9995176792144775, 0.00040865709888748825, 2.72958709501836e-06]
# True Label: 2, Predicted: 3, Confidence: 0.9295
# Full Probabilities: [1.794723175407853e-05, 0.0015660468488931656, 0.06893116980791092, 0.9294848442077637]
# True Label: 2, Predicted: 1, Confidence: 0.6122
# Full Probabilities: [3.3260061172768474e-05, 0.6122154593467712, 0.38764169812202454, 0.00010960209328914061]
# True Label: 2, Predicted: 3, Confidence: 0.8125
# Full Probabilities: [7.30867322999984e-05, 0.019940460100769997, 0.16749447584152222, 0.8124920129776001]
# True Label: 2, Predicted: 1, Confidence: 0.9810
# Full Probabilities: [0.0002316026802873239, 0.9810248613357544, 0.0005012438632547855, 0.018242379650473595]
# True Label: 2, Predicted: 1, Confidence: 1.0000
# Full Probabilities: [4.454582722246414e-06, 0.9999865293502808, 1.3064388895145385e-06, 7.778189683449455e-06]
# True Label: 2, Predicted: 1, Confidence: 0.9978
# Full Probabilities: [1.9373694158275612e-05, 0.9977914094924927, 0.0009566809749230742, 0.0012325349962338805]
# True Label: 2, Predicted: 1, Confidence: 0.7775
# Full Probabilities: [2.8983509764657356e-05, 0.7775335311889648, 0.2222709208726883, 0.00016657303785905242]
# True Label: 2, Predicted: 1, Confidence: 0.9410
# Full Probabilities: [3.780278711928986e-05, 0.9409845471382141, 0.058633334934711456, 0.0003443212481215596]
# True Label: 2, Predicted: 3, Confidence: 0.8912
# Full Probabilities: [8.221962161769625e-06, 0.0005173597601242363, 0.10829637944698334, 0.8911780118942261]
# True Label: 2, Predicted: 3, Confidence: 0.9373
# Full Probabilities: [0.0001648732868488878, 0.002136486815288663, 0.0604105070233345, 0.9372881650924683]
# True Label: 3, Predicted: 2, Confidence: 0.9685
# Full Probabilities: [3.3970660297200084e-05, 0.02380562014877796, 0.9685189723968506, 0.007641511969268322]
# True Label: 3, Predicted: 1, Confidence: 0.9374
# Full Probabilities: [6.17625773884356e-05, 0.9373682737350464, 0.0625697523355484, 2.352812060735232e-07]
# True Label: 3, Predicted: 2, Confidence: 0.9973
# Full Probabilities: [3.1738070447318023e-06, 0.0021653147414326668, 0.9973247051239014, 0.0005068277241662145]
# True Label: 3, Predicted: 2, Confidence: 0.7683
# Full Probabilities: [1.1367612387402914e-05, 0.00010498019400984049, 0.7682552337646484, 0.23162849247455597]
# True Label: 3, Predicted: 2, Confidence: 0.9728
# Full Probabilities: [1.5267753042280674e-05, 0.005146197974681854, 0.9727621078491211, 0.022076420485973358]
# True Label: 3, Predicted: 2, Confidence: 0.9192
# Full Probabilities: [4.051002179039642e-06, 3.078768349951133e-05, 0.9192295074462891, 0.08073562383651733]
# True Label: 3, Predicted: 2, Confidence: 0.9997
# Full Probabilities: [1.516612542218354e-07, 0.00027648216928355396, 0.9997062087059021, 1.717388840916101e-05]
# True Label: 3, Predicted: 2, Confidence: 0.9872
# Full Probabilities: [1.4344852388603613e-05, 0.007210376672446728, 0.9872109889984131, 0.005564398597925901]
# True Label: 3, Predicted: 1, Confidence: 0.8676
# Full Probabilities: [0.0003586477250792086, 0.8676156401634216, 0.0341118648648262, 0.09791383892297745]
# True Label: 3, Predicted: 2, Confidence: 0.5857
# Full Probabilities: [9.871078509604558e-05, 0.027417736127972603, 0.5857017040252686, 0.38678184151649475]
# True Label: 3, Predicted: 1, Confidence: 0.8976
# Full Probabilities: [0.00018187817477155477, 0.8976205587387085, 0.0030235133599489927, 0.09917397797107697]
# True Label: 3, Predicted: 2, Confidence: 0.9966
# Full Probabilities: [1.1360898497514427e-06, 8.034976053750142e-05, 0.9965665340423584, 0.003351927502080798]
# True Label: 3, Predicted: 2, Confidence: 0.9994
# Full Probabilities: [2.528785785216314e-07, 0.0005531309288926423, 0.9993886947631836, 5.7887518778443336e-05]
# True Label: 3, Predicted: 2, Confidence: 0.9848
# Full Probabilities: [1.137086542257748e-06, 0.015243600122630596, 0.9847538471221924, 1.3850786899638479e-06]
# True Label: 3, Predicted: 2, Confidence: 0.8418
# Full Probabilities: [3.306253347545862e-05, 9.261727973353118e-05, 0.8417601585388184, 0.1581142097711563]
# True Label: 3, Predicted: 1, Confidence: 0.9913
# Full Probabilities: [9.773737838258967e-05, 0.9912818670272827, 0.0037229531444609165, 0.004897459875792265]
# True Label: 3, Predicted: 1, Confidence: 0.9650
# Full Probabilities: [3.3942011214094236e-05, 0.965035080909729, 0.034915365278720856, 1.5692328815930523e-05]
# True Label: 3, Predicted: 1, Confidence: 0.9999
# Full Probabilities: [3.321777330711484e-05, 0.9999085664749146, 4.897764665656723e-05, 9.153593964583706e-06]
# True Label: 3, Predicted: 1, Confidence: 0.9833
# Full Probabilities: [0.00013367726933211088, 0.9832747578620911, 0.012918001040816307, 0.0036736405454576015]
# True Label: 3, Predicted: 1, Confidence: 0.5485
# Full Probabilities: [0.0004601093241944909, 0.5484516024589539, 0.001745901769027114, 0.44934237003326416]
# True Label: 3, Predicted: 1, Confidence: 0.5442
# Full Probabilities: [0.00033157289726659656, 0.54417484998703, 0.257946252822876, 0.19754725694656372]
# True Label: 3, Predicted: 2, Confidence: 0.6707
# Full Probabilities: [1.3873634998162743e-05, 3.523860141285695e-05, 0.6706501841545105, 0.3293007016181946]
# True Label: 3, Predicted: 1, Confidence: 0.9399
# Full Probabilities: [3.3511129004182294e-05, 0.9398501515388489, 0.058390580117702484, 0.0017257119761779904]
